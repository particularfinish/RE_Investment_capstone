# %% [markdown]
# # 4 Modeling<a id='5_Modeling'></a>

# %% [markdown]
# ## 4.1 Introduction<a id='5.2_Introduction'></a>

# %% [markdown]
# In this notebook, we now take our model for predicting market rent and leverage it to gain some insights into which houses for sale may make good investments, as explore the sensitivity of changes to various housing parameters. Note that this relies on the implicit assumption that the market rents upon which we trained and tested the model reflect the actual market rent that people will pay, no more and no less. Essentially this assumes prices are set by a free market.

# %% [markdown]
# ## 4.2 Imports<a id='5.3_Imports'></a>

# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version
from sklearn.model_selection import cross_validate

# %% [markdown]
# ## 4.3 Load Model<a id='5.4_Load_Model'></a>

# %%
# This isn't exactly production-grade, but a quick check for development
# These checks can save some head-scratching in development when moving from
# one python environment to another, for example
expected_model_version = 1.0
model_path = '../models/market_rent_model.pkl'
if os.path.exists(model_path):
    with open(model_path, 'rb') as f:
        model = pickle.load(f)
    if model.version != expected_model_version:
        print("Expected model version doesn't match version loaded")
    if model.sklearn_version != sklearn_version:
        print("Warning: model created under different sklearn version")
else:
    print("Expected model not found")

# %% [markdown]
# ## 4.4 Load Data<a id='5.5_Load_Data'></a>

# %%
sale_data = pd.read_csv('../data/sale_data_I.csv')

# %%
corporate_data = pd.read_csv('../data/corporate_data_I.csv')

# %%
sale_data.T
# Out:
#                                                                                      0    \
# address                                                               2920 Benton Street
# city                                                                         Wheat Ridge
# zipcode                                                                            80214
# beds                                                                                   4
# baths                                                                                  2
# sqft                                                                                1751
# value                                                                             750000
# taxes                                                                               1664
# lat                                                                            39.759313
# lng                                                                          -105.055104
# monthly_hoa                                                                          0.0
# districtMatch                                       Jefferson County R-1 School District
# percentFreeDiscLunch                                                               37.16
# percentofAfricanAmericanStudents                                                    1.45
# percentofAsianStudents                                                              2.89
# percentofHispanicStudents                                                          26.14
# percentofIndianStudents                                                             0.62
# percentofPacificIslanderStudents                                                    0.14
# percentofTwoOrMoreRaceStudents                                                      4.07
# percentofWhiteStudents                                                              64.7
# rankMovement                                                                      -23.29
# Median household income (in 2019 dollars), 2015...                               57659.0
# beds_3                                                                                 0
# beds_4                                                                                 1
# beds_5                                                                                 0
# baths_2                                                                                1
# baths_3                                                                                0
# baths_4                                                                                0
#
#                                                                                 1    \
# address                                                           3831 Routt Street
# city                                                                    Wheat Ridge
# zipcode                                                                       80033
# beds                                                                              4
# baths                                                                             3
# sqft                                                                           2810
# value                                                                        735000
# taxes                                                                          3132
# lat                                                                       39.770602
# lng                                                                      -105.12752
# monthly_hoa                                                                     0.0
# districtMatch                                       Denver County 1 School District
# percentFreeDiscLunch                                                          65.04
# percentofAfricanAmericanStudents                                              12.19
# percentofAsianStudents                                                         2.77
# percentofHispanicStudents                                                     53.59
# percentofIndianStudents                                                        0.71
# percentofPacificIslanderStudents                                                0.4
# percentofTwoOrMoreRaceStudents                                                 3.71
# percentofWhiteStudents                                                        26.62
# rankMovement                                                                 -34.32
# Median household income (in 2019 dollars), 2015...                          57659.0
# beds_3                                                                            0
# beds_4                                                                            1
# beds_5                                                                            0
# baths_2                                                                           0
# baths_3                                                                           1
# baths_4                                                                           0
#
#                                                                                 2    \
# address                                                     3310 Independence Court
# city                                                                    Wheat Ridge
# zipcode                                                                       80033
# beds                                                                              3
# baths                                                                             2
# sqft                                                                           2367
# value                                                                        700000
# taxes                                                                          2359
# lat                                                                       39.763183
# lng                                                                     -105.105296
# monthly_hoa                                                                     0.0
# districtMatch                                       Denver County 1 School District
# percentFreeDiscLunch                                                          65.04
# percentofAfricanAmericanStudents                                              12.19
# percentofAsianStudents                                                         2.77
# percentofHispanicStudents                                                     53.59
# percentofIndianStudents                                                        0.71
# percentofPacificIslanderStudents                                                0.4
# percentofTwoOrMoreRaceStudents                                                 3.71
# percentofWhiteStudents                                                        26.62
# rankMovement                                                                 -34.32
# Median household income (in 2019 dollars), 2015...                          57659.0
# beds_3                                                                            1
# beds_4                                                                            0
# beds_5                                                                            0
# baths_2                                                                           1
# baths_3                                                                           0
# baths_4                                                                           0
#
#                                                                                 3    \
# address                                                         3505 Holland Street
# city                                                                    Wheat Ridge
# zipcode                                                                       80033
# beds                                                                              3
# baths                                                                             3
# sqft                                                                           2686
# value                                                                        700000
# taxes                                                                          2495
# lat                                                                       39.765798
# lng                                                                     -105.102271
# monthly_hoa                                                                     0.0
# districtMatch                                       Denver County 1 School District
# percentFreeDiscLunch                                                          65.04
# percentofAfricanAmericanStudents                                              12.19
# percentofAsianStudents                                                         2.77
# percentofHispanicStudents                                                     53.59
# percentofIndianStudents                                                        0.71
# percentofPacificIslanderStudents                                                0.4
# percentofTwoOrMoreRaceStudents                                                 3.71
# percentofWhiteStudents                                                        26.62
# rankMovement                                                                 -34.32
# Median household income (in 2019 dollars), 2015...                          57659.0
# beds_3                                                                            1
# beds_4                                                                            0
# beds_5                                                                            0
# baths_2                                                                           0
# baths_3                                                                           1
# baths_4                                                                           0
#
#                                                                                      4    \
# address                                                              2900 Webster Street
# city                                                                         Wheat Ridge
# zipcode                                                                            80033
# beds                                                                                   3
# baths                                                                                  3
# sqft                                                                                2553
# value                                                                             660000
# taxes                                                                               2509
# lat                                                                            39.758627
# lng                                                                          -105.079574
# monthly_hoa                                                                          0.0
# districtMatch                                       Jefferson County R-1 School District
# percentFreeDiscLunch                                                               37.16
# percentofAfricanAmericanStudents                                                    1.45
# percentofAsianStudents                                                              2.89
# percentofHispanicStudents                                                          26.14
# percentofIndianStudents                                                             0.62
# percentofPacificIslanderStudents                                                    0.14
# percentofTwoOrMoreRaceStudents                                                      4.07
# percentofWhiteStudents                                                              64.7
# rankMovement                                                                      -23.29
# Median household income (in 2019 dollars), 2015...                               57659.0
# beds_3                                                                                 1
# beds_4                                                                                 0
# beds_5                                                                                 0
# baths_2                                                                                0
# baths_3                                                                                1
# baths_4                                                                                0
#
#                                                                                 5    \
# address                                                           3665 Quail Street
# city                                                                    Wheat Ridge
# zipcode                                                                       80033
# beds                                                                              3
# baths                                                                             3
# sqft                                                                           2900
# value                                                                        650000
# taxes                                                                          3101
# lat                                                                        39.76757
# lng                                                                     -105.123944
# monthly_hoa                                                                     0.0
# districtMatch                                       Denver County 1 School District
# percentFreeDiscLunch                                                          65.04
# percentofAfricanAmericanStudents                                              12.19
# percentofAsianStudents                                                         2.77
# percentofHispanicStudents                                                     53.59
# percentofIndianStudents                                                        0.71
# percentofPacificIslanderStudents                                                0.4
# percentofTwoOrMoreRaceStudents                                                 3.71
# percentofWhiteStudents                                                        26.62
# rankMovement                                                                 -34.32
# Median household income (in 2019 dollars), 2015...                          57659.0
# beds_3                                                                            1
# beds_4                                                                            0
# beds_5                                                                            0
# baths_2                                                                           0
# baths_3                                                                           1
# baths_4                                                                           0
#
#                                                                                    6    \
# address                                                             12143 W 31st Place
# city                                                                       Wheat Ridge
# zipcode                                                                          80215
# beds                                                                                 5
# baths                                                                                3
# sqft                                                                              2989
# value                                                                           650000
# taxes                                                                             3674
# lat                                                                          39.761304
# lng                                                                        -105.134956
# monthly_hoa                                                                        0.0
# districtMatch                                       Adams-Arapahoe 28J School District
# percentFreeDiscLunch                                                             77.81
# percentofAfricanAmericanStudents                                                 16.37
# percentofAsianStudents                                                            5.28
# percentofHispanicStudents                                                        55.53
# percentofIndianStudents                                                           0.74
# percentofPacificIslanderStudents                                                  1.07
# percentofTwoOrMoreRaceStudents                                                    6.08
# percentofWhiteStudents                                                           14.92
# rankMovement                                                                    -39.37
# Median household income (in 2019 dollars), 2015...                             57659.0
# beds_3                                                                               0
# beds_4                                                                               0
# beds_5                                                                               1
# baths_2                                                                              0
# baths_3                                                                              1
# baths_4                                                                              0
#
#                                                                                      7    \
# address                                                                4495 Vance Street
# city                                                                         Wheat Ridge
# zipcode                                                                            80033
# beds                                                                                   4
# baths                                                                                  3
# sqft                                                                                2594
# value                                                                             649500
# taxes                                                                               2379
# lat                                                                            39.778234
# lng                                                                           -105.07945
# monthly_hoa                                                                          0.0
# districtMatch                                       Jefferson County R-1 School District
# percentFreeDiscLunch                                                               37.16
# percentofAfricanAmericanStudents                                                    1.45
# percentofAsianStudents                                                              2.89
# percentofHispanicStudents                                                          26.14
# percentofIndianStudents                                                             0.62
# percentofPacificIslanderStudents                                                    0.14
# percentofTwoOrMoreRaceStudents                                                      4.07
# percentofWhiteStudents                                                              64.7
# rankMovement                                                                      -23.29
# Median household income (in 2019 dollars), 2015...                               57659.0
# beds_3                                                                                 0
# beds_4                                                                                 1
# beds_5                                                                                 0
# baths_2                                                                                0
# baths_3                                                                                1
# baths_4                                                                                0
#
#                                                                                    8    \
# address                                                            10945 W 45th Avenue
# city                                                                       Wheat Ridge
# zipcode                                                                          80033
# beds                                                                                 4
# baths                                                                                2
# sqft                                                                              2240
# value                                                                           644999
# taxes                                                                             2809
# lat                                                                          39.779666
# lng                                                                        -105.120405
# monthly_hoa                                                                        0.0
# districtMatch                                       Adams-Arapahoe 28J School District
# percentFreeDiscLunch                                                             77.81
# percentofAfricanAmericanStudents                                                 16.37
# percentofAsianStudents                                                            5.28
# percentofHispanicStudents                                                        55.53
# percentofIndianStudents                                                           0.74
# percentofPacificIslanderStudents                                                  1.07
# percentofTwoOrMoreRaceStudents                                                    6.08
# percentofWhiteStudents                                                           14.92
# rankMovement                                                                    -39.37
# Median household income (in 2019 dollars), 2015...                             57659.0
# beds_3                                                                               0
# beds_4                                                                               1
# beds_5                                                                               0
# baths_2                                                                              1
# baths_3                                                                              0
# baths_4                                                                              0
#
#                                                                                9    \
# address                                                         6415 W 29th Avenue
# city                                                                   Wheat Ridge
# zipcode                                                                      80214
# beds                                                                             3
# baths                                                                            2
# sqft                                                                          1577
# value                                                                       600000
# taxes                                                                         2503
# lat                                                                      39.759231
# lng                                                                     -105.06739
# monthly_hoa                                                                    0.0
# districtMatch                                       Westminster 50 School District
# percentFreeDiscLunch                                                         80.55
# percentofAfricanAmericanStudents                                              1.94
# percentofAsianStudents                                                        3.94
# percentofHispanicStudents                                                    74.73
# percentofIndianStudents                                                       0.68
# percentofPacificIslanderStudents                                              0.59
# percentofTwoOrMoreRaceStudents                                                2.25
# percentofWhiteStudents                                                       15.88
# rankMovement                                                                -19.69
# Median household income (in 2019 dollars), 2015...                         57659.0
# beds_3                                                                           1
# beds_4                                                                           0
# beds_5                                                                           0
# baths_2                                                                          1
# baths_3                                                                          0
# baths_4                                                                          0
#
#                                                     ...  \
# address                                             ...
# city                                                ...
# zipcode                                             ...
# beds                                                ...
# baths                                               ...
# sqft                                                ...
# value                                               ...
# taxes                                               ...
# lat                                                 ...
# lng                                                 ...
# monthly_hoa                                         ...
# districtMatch                                       ...
# percentFreeDiscLunch                                ...
# percentofAfricanAmericanStudents                    ...
# percentofAsianStudents                              ...
# percentofHispanicStudents                           ...
# percentofIndianStudents                             ...
# percentofPacificIslanderStudents                    ...
# percentofTwoOrMoreRaceStudents                      ...
# percentofWhiteStudents                              ...
# rankMovement                                        ...
# Median household income (in 2019 dollars), 2015...  ...
# beds_3                                              ...
# beds_4                                              ...
# beds_5                                              ...
# baths_2                                             ...
# baths_3                                             ...
# baths_4                                             ...
#
#                                                                                 615  \
# address                                                      3389 W Aqueduct Avenue
# city                                                                      Littleton
# zipcode                                                                       80123
# beds                                                                              4
# baths                                                                             2
# sqft                                                                           1703
# value                                                                        550000
# taxes                                                                          2927
# lat                                                                       39.619171
# lng                                                                     -105.034327
# monthly_hoa                                                                     0.0
# districtMatch                                       Denver County 1 School District
# percentFreeDiscLunch                                                          65.04
# percentofAfricanAmericanStudents                                              12.19
# percentofAsianStudents                                                         2.77
# percentofHispanicStudents                                                     53.59
# percentofIndianStudents                                                        0.71
# percentofPacificIslanderStudents                                                0.4
# percentofTwoOrMoreRaceStudents                                                 3.71
# percentofWhiteStudents                                                        26.62
# rankMovement                                                                 -34.32
# Median household income (in 2019 dollars), 2015...                          76015.0
# beds_3                                                                            0
# beds_4                                                                            1
# beds_5                                                                            0
# baths_2                                                                           1
# baths_3                                                                           0
# baths_4                                                                           0
#
#                                                                                 616  \
# address                                                         4674 S Estes Street
# city                                                                      Littleton
# zipcode                                                                       80123
# beds                                                                              3
# baths                                                                             3
# sqft                                                                           1635
# value                                                                        525000
# taxes                                                                          1927
# lat                                                                       39.632219
# lng                                                                     -105.095868
# monthly_hoa                                                                     0.0
# districtMatch                                       Denver County 1 School District
# percentFreeDiscLunch                                                          65.04
# percentofAfricanAmericanStudents                                              12.19
# percentofAsianStudents                                                         2.77
# percentofHispanicStudents                                                     53.59
# percentofIndianStudents                                                        0.71
# percentofPacificIslanderStudents                                                0.4
# percentofTwoOrMoreRaceStudents                                                 3.71
# percentofWhiteStudents                                                        26.62
# rankMovement                                                                 -34.32
# Median household income (in 2019 dollars), 2015...                          76015.0
# beds_3                                                                            1
# beds_4                                                                            0
# beds_5                                                                            0
# baths_2                                                                           0
# baths_3                                                                           1
# baths_4                                                                           0
#
#                                                                                 617  \
# address                                                       4934 S Newcombe Court
# city                                                                      Littleton
# zipcode                                                                       80127
# beds                                                                              2
# baths                                                                             3
# sqft                                                                           2498
# value                                                                        515000
# taxes                                                                          2992
# lat                                                                       39.627429
# lng                                                                     -105.118622
# monthly_hoa                                                                   373.0
# districtMatch                                       Denver County 1 School District
# percentFreeDiscLunch                                                          65.04
# percentofAfricanAmericanStudents                                              12.19
# percentofAsianStudents                                                         2.77
# percentofHispanicStudents                                                     53.59
# percentofIndianStudents                                                        0.71
# percentofPacificIslanderStudents                                                0.4
# percentofTwoOrMoreRaceStudents                                                 3.71
# percentofWhiteStudents                                                        26.62
# rankMovement                                                                 -34.32
# Median household income (in 2019 dollars), 2015...                          76015.0
# beds_3                                                                            0
# beds_4                                                                            0
# beds_5                                                                            0
# baths_2                                                                           0
# baths_3                                                                           1
# baths_4                                                                           0
#
#                                                                                618  \
# address                                                   10722 W Dumbarton Circle
# city                                                                     Littleton
# zipcode                                                                      80127
# beds                                                                             2
# baths                                                                            2
# sqft                                                                          1735
# value                                                                       515000
# taxes                                                                         2225
# lat                                                                      39.626647
# lng                                                                    -105.119379
# monthly_hoa                                                                  374.0
# districtMatch                                       Westminster 50 School District
# percentFreeDiscLunch                                                         80.55
# percentofAfricanAmericanStudents                                              1.94
# percentofAsianStudents                                                        3.94
# percentofHispanicStudents                                                    74.73
# percentofIndianStudents                                                       0.68
# percentofPacificIslanderStudents                                              0.59
# percentofTwoOrMoreRaceStudents                                                2.25
# percentofWhiteStudents                                                       15.88
# rankMovement                                                                -19.69
# Median household income (in 2019 dollars), 2015...                         76015.0
# beds_3                                                                           0
# beds_4                                                                           0
# beds_5                                                                           0
# baths_2                                                                          1
# baths_3                                                                          0
# baths_4                                                                          0
#
#                                                                                 619  \
# address                                                         2486 Ingalls Street
# city                                                                      Edgewater
# zipcode                                                                       80214
# beds                                                                              3
# baths                                                                             2
# sqft                                                                           1239
# value                                                                        600000
# taxes                                                                          2481
# lat                                                                       39.752725
# lng                                                                     -105.063489
# monthly_hoa                                                                     0.0
# districtMatch                                       Denver County 1 School District
# percentFreeDiscLunch                                                          65.04
# percentofAfricanAmericanStudents                                              12.19
# percentofAsianStudents                                                         2.77
# percentofHispanicStudents                                                     53.59
# percentofIndianStudents                                                        0.71
# percentofPacificIslanderStudents                                                0.4
# percentofTwoOrMoreRaceStudents                                                 3.71
# percentofWhiteStudents                                                        26.62
# rankMovement                                                                 -34.32
# Median household income (in 2019 dollars), 2015...                          56028.0
# beds_3                                                                            1
# beds_4                                                                            0
# beds_5                                                                            0
# baths_2                                                                           1
# baths_3                                                                           0
# baths_4                                                                           0
#
#                                                                                 620  \
# address                                                          2500 Harlan Street
# city                                                                      Edgewater
# zipcode                                                                       80214
# beds                                                                              2
# baths                                                                             2
# sqft                                                                            932
# value                                                                        465000
# taxes                                                                          1729
# lat                                                                       39.753142
# lng                                                                     -105.062303
# monthly_hoa                                                                     0.0
# districtMatch                                       Denver County 1 School District
# percentFreeDiscLunch                                                          65.04
# percentofAfricanAmericanStudents                                              12.19
# percentofAsianStudents                                                         2.77
# percentofHispanicStudents                                                     53.59
# percentofIndianStudents                                                        0.71
# percentofPacificIslanderStudents                                                0.4
# percentofTwoOrMoreRaceStudents                                                 3.71
# percentofWhiteStudents                                                        26.62
# rankMovement                                                                 -34.32
# Median household income (in 2019 dollars), 2015...                          56028.0
# beds_3                                                                            0
# beds_4                                                                            0
# beds_5                                                                            0
# baths_2                                                                           1
# baths_3                                                                           0
# baths_4                                                                           0
#
#                                                                                    621  \
# address                                                             6150 Locust Street
# city                                                                     Commerce City
# zipcode                                                                          80022
# beds                                                                                 4
# baths                                                                                2
# sqft                                                                              1824
# value                                                                           450000
# taxes                                                                             1116
# lat                                                                          39.808244
# lng                                                                        -104.913649
# monthly_hoa                                                                        0.0
# districtMatch                                       Adams-Arapahoe 28J School District
# percentFreeDiscLunch                                                             77.81
# percentofAfricanAmericanStudents                                                 16.37
# percentofAsianStudents                                                            5.28
# percentofHispanicStudents                                                        55.53
# percentofIndianStudents                                                           0.74
# percentofPacificIslanderStudents                                                  1.07
# percentofTwoOrMoreRaceStudents                                                    6.08
# percentofWhiteStudents                                                           14.92
# rankMovement                                                                    -39.37
# Median household income (in 2019 dollars), 2015...                             77065.0
# beds_3                                                                               0
# beds_4                                                                               1
# beds_5                                                                               0
# baths_2                                                                              1
# baths_3                                                                              0
# baths_4                                                                              0
#
#                                                                                 622  \
# address                                                          7095 E 67th Avenue
# city                                                                  Commerce City
# zipcode                                                                       80022
# beds                                                                              3
# baths                                                                             3
# sqft                                                                           1932
# value                                                                        440000
# taxes                                                                          1974
# lat                                                                       39.818618
# lng                                                                      -104.90579
# monthly_hoa                                                                     0.0
# districtMatch                                       Denver County 1 School District
# percentFreeDiscLunch                                                          65.04
# percentofAfricanAmericanStudents                                              12.19
# percentofAsianStudents                                                         2.77
# percentofHispanicStudents                                                     53.59
# percentofIndianStudents                                                        0.71
# percentofPacificIslanderStudents                                                0.4
# percentofTwoOrMoreRaceStudents                                                 3.71
# percentofWhiteStudents                                                        26.62
# rankMovement                                                                 -34.32
# Median household income (in 2019 dollars), 2015...                          77065.0
# beds_3                                                                            1
# beds_4                                                                            0
# beds_5                                                                            0
# baths_2                                                                           0
# baths_3                                                                           1
# baths_4                                                                           0
#
#                                                                                      623  \
# address                                                                6945 Olive Street
# city                                                                       Commerce City
# zipcode                                                                            80022
# beds                                                                                   3
# baths                                                                                  1
# sqft                                                                                1026
# value                                                                             405000
# taxes                                                                               1628
# lat                                                                            39.822637
# lng                                                                          -104.908281
# monthly_hoa                                                                          0.0
# districtMatch                                       Jefferson County R-1 School District
# percentFreeDiscLunch                                                               37.16
# percentofAfricanAmericanStudents                                                    1.45
# percentofAsianStudents                                                              2.89
# percentofHispanicStudents                                                          26.14
# percentofIndianStudents                                                             0.62
# percentofPacificIslanderStudents                                                    0.14
# percentofTwoOrMoreRaceStudents                                                      4.07
# percentofWhiteStudents                                                              64.7
# rankMovement                                                                      -23.29
# Median household income (in 2019 dollars), 2015...                               77065.0
# beds_3                                                                                 1
# beds_4                                                                                 0
# beds_5                                                                                 0
# baths_2                                                                                0
# baths_3                                                                                0
# baths_4                                                                                0
#
#                                                                                624
# address                                                      7831 Hollywood Street
# city                                                                 Commerce City
# zipcode                                                                      80022
# beds                                                                             4
# baths                                                                            2
# sqft                                                                          1550
# value                                                                       384900
# taxes                                                                         1518
# lat                                                                      39.838775
# lng                                                                      -104.9227
# monthly_hoa                                                                    0.0
# districtMatch                                       Westminster 50 School District
# percentFreeDiscLunch                                                         80.55
# percentofAfricanAmericanStudents                                              1.94
# percentofAsianStudents                                                        3.94
# percentofHispanicStudents                                                    74.73
# percentofIndianStudents                                                       0.68
# percentofPacificIslanderStudents                                              0.59
# percentofTwoOrMoreRaceStudents                                                2.25
# percentofWhiteStudents                                                       15.88
# rankMovement                                                                -19.69
# Median household income (in 2019 dollars), 2015...                         77065.0
# beds_3                                                                           0
# beds_4                                                                           1
# beds_5                                                                           0
# baths_2                                                                          1
# baths_3                                                                          0
# baths_4                                                                          0
#
# [28 rows x 625 columns]

# %% [markdown]
# ## 4.5 Refit Model On All Available Data<a id='5.6_Refit_Model_On_All_Available_Data_'></a>

# %% [markdown]
# We now want to refit the model using all available data.

# %%
# set aside the address information
address_list = ['address', 'zipcode', 'lat', 'lng', 'districtMatch', 'city', 'beds', 'baths']
X = corporate_data.drop(columns='market_rent')
y = corporate_data.market_rent
X.drop(columns=address_list, inplace=True)

# %%
len(X), len(y)
# Out:
# (188, 188)

# %%
model.fit(X, y)
# Out:
# Lasso(alpha=0.03, max_iter=10000, normalize=True)

# %%
cv_results = cross_validate(model, X, y, scoring='neg_mean_absolute_error', cv=5, n_jobs=-1)

# %%
cv_results['test_score']
# Out:
# array([-136.06453433, -105.54851897, -107.70451366, -103.08504779,
#        -151.92856322])

# %%
mae_mean, mae_std = np.mean(-1 * cv_results['test_score']), np.std(-1 * cv_results['test_score'])
mae_mean, mae_std
# Out:
# (120.86623559388606, 19.5953590857118)

# %% [markdown]
# These numbers will inevitably be different to those in the previous step that used a different training data set. They should, however, be consistent. It's important to appreciate that estimates of model performance are subject to the noise and uncertainty of data!

# %% [markdown]
# ## 4.6 Calculate Expected Market Rent From The Model<a id='5.7_Calculate_Expected_Market_Rent_From_The_Model'></a>

# %%
sale_data.columns
# Out:
# Index(['address', 'city', 'zipcode', 'beds', 'baths', 'sqft', 'value', 'taxes',
#        'lat', 'lng', 'monthly_hoa', 'districtMatch', 'percentFreeDiscLunch',
#        'percentofAfricanAmericanStudents', 'percentofAsianStudents',
#        'percentofHispanicStudents', 'percentofIndianStudents',
#        'percentofPacificIslanderStudents', 'percentofTwoOrMoreRaceStudents',
#        'percentofWhiteStudents', 'rankMovement',
#        'Median household income (in 2019 dollars), 2015-2019', 'beds_3',
#        'beds_4', 'beds_5', 'baths_2', 'baths_3', 'baths_4'],
#       dtype='object')

# %%
sales_drop = ['address', 'zipcode', 'lat', 'lng', 'districtMatch', 'city', 'beds', 'baths', 'monthly_hoa', 'taxes']
X_sd = sale_data.copy()
X_sd.drop(columns=sales_drop, inplace=True)
X_sd.columns, X_sd.shape
# Out:
# (Index(['sqft', 'value', 'percentFreeDiscLunch',
#         'percentofAfricanAmericanStudents', 'percentofAsianStudents',
#         'percentofHispanicStudents', 'percentofIndianStudents',
#         'percentofPacificIslanderStudents', 'percentofTwoOrMoreRaceStudents',
#         'percentofWhiteStudents', 'rankMovement',
#         'Median household income (in 2019 dollars), 2015-2019', 'beds_3',
#         'beds_4', 'beds_5', 'baths_2', 'baths_3', 'baths_4'],
#        dtype='object'),
#  (625, 18))

# %%
sd_pred = model.predict(X_sd)

# %%
sale_data['market_rent'] = np.round(sd_pred, 2)

# %%
round(sale_data['market_rent'].mean(), 2)
# Out:
# 2661.23

# %% [markdown]
# ## 4.7 Market Rents In Market Context<a id='4.8_Market_Rents_In_Market_Context'></a>

# %% [markdown]
# Features that came up as important in the modeling (not just our final, random forest model) included:
# * Number of bathrooms
# * Square footage
# * Value of the house
# * Median income of city

# %% [markdown]
# The private investor with whom I spoke described his formula for Return-On-Investment. He buys with cash usually, but uses a cost of money of 4% regardless. He estimates the cost of money on the total value of the house at any given time (in our example, the sales price). He uses 1.5 times the monthly rent as a number for maintenance, 0.0056% annually for taxes, and 8% of the rent as administrative overhead. Let's use this information to calculate the potential ROI of the rental properties.

# %%
sale_data.columns
# Out:
# Index(['address', 'city', 'zipcode', 'beds', 'baths', 'sqft', 'value', 'taxes',
#        'lat', 'lng', 'monthly_hoa', 'districtMatch', 'percentFreeDiscLunch',
#        'percentofAfricanAmericanStudents', 'percentofAsianStudents',
#        'percentofHispanicStudents', 'percentofIndianStudents',
#        'percentofPacificIslanderStudents', 'percentofTwoOrMoreRaceStudents',
#        'percentofWhiteStudents', 'rankMovement',
#        'Median household income (in 2019 dollars), 2015-2019', 'beds_3',
#        'beds_4', 'beds_5', 'baths_2', 'baths_3', 'baths_4', 'market_rent'],
#       dtype='object')

# %%
# Calculate ROI
sale_data['ROI'] = (12 * sale_data.market_rent) - (0.04 * sale_data.value) - \
    (sale_data.taxes) - (12 * sale_data.monthly_hoa) - (1.5 * sale_data.market_rent) - (12 * 0.08 * sale_data.market_rent)

# %% [markdown]
# ### 4.8 Positive ROI<a id='4.9_Positive_ROI'></a>

# %% [markdown]
# Will any of the houses for sale generate a positive ROI according to our model?

# %%
plt.hist(sale_data['ROI'])
plt.show()

# %% [markdown]
# It looks like somewhat less than 50% of properties may generate positive ROI.
# Let's look at the corporate properties and calculate their ROI using the same formula, and find the threshold for the ROI at some percentile.

# %%
# Calculate ROI
corporate_data['ROI'] = (12 * corporate_data.market_rent) - (0.04 * corporate_data.value) - \
    (corporate_data.value * 0.0056) - - (1.5 * corporate_data.market_rent) - (12 * 0.08 * corporate_data.market_rent)

# %%
# calculate an ROI of the 25% percentile from corporate properties
corporate25 = corporate_data['ROI'].quantile(.25)
print(corporate25)
# Out:
# 10518.411552

# %%
# How many of the properties for sale currently exceed the ROI of the properties which lie at the 30 percentile
top = sale_data[sale_data['ROI']> corporate25]
top.head(), top.shape
# Out:
# (Empty DataFrame
#  Columns: [address, city, zipcode, beds, baths, sqft, value, taxes, lat, lng, monthly_hoa, districtMatch, percentFreeDiscLunch, percentofAfricanAmericanStudents, percentofAsianStudents, percentofHispanicStudents, percentofIndianStudents, percentofPacificIslanderStudents, percentofTwoOrMoreRaceStudents, percentofWhiteStudents, rankMovement, Median household income (in 2019 dollars), 2015-2019, beds_3, beds_4, beds_5, baths_2, baths_3, baths_4, market_rent, ROI]
#  Index: []
#
#  [0 rows x 30 columns],
#  (0, 30))

# %% [markdown]
# Currently there aren't any properties which exceed the ROI of the 25th percentile of the ROI of the corporate properties.

# %% [markdown]
# ## 4.9 Summary<a id='5.10_Summary'></a>

# %% [markdown]
# Currently, there are not any houses for sale that meet the determined criteria for the corporate investor.

# %% [markdown]
# ## 4.10 Further work<a id='5.11_Further_work'></a>

# %% [markdown]
# Our current dataset of corporate investment properties consist of properties which have been listed on that company's website. This means we only have access to properties which have experienced "turnover" - that is, a change in tenancy. This may lead to the properties listed being a biased subset of all of the owned properties. Perhaps these properties are in more depressed neighborhoods, or are overpriced.  Additionally there are only 188 such properties, and our modeling showed that more properties would lead to a more robust model. .
#
# The following would be interesting to pursue:
#
# -  Would like to know how long the corporation has owned the properties, and how they purchased them
# -  Would like to separate for-sale data by full baths / half baths
# -  Eventually would be nice to move the demographics/income information to the school level, instead of the district, because the district level information is a bit averaged out.
#
#
# Value of a house is intrinsically tied to other factors such as number of bathrooms, sqft, bedrooms, median income in the area and all of the other factors which we explored. It may be better to pursue a model for market rents that does *not* take into account the current value, which changes all the time.
#
# Many of the yearly ROI costs were estimated. This particular corporate investor puts a larger share of maintenance onto the tenants. Indeed, this corporation and others like it have been the subject of The Atlantic article, "When Wall Street is Your Landlord": https://www.theatlantic.com/technology/archive/2019/02/single-family-landlords-wall-street/582394/
